# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_time_series = pd.read_csv("./TimeSeries.csv", index_col=0)
df_time_series.head()
# Out:
#                                   P2
# timestamp
# 2018-09-01 03:00:00+03:00  17.541667
# 2018-09-01 04:00:00+03:00  15.800000
# 2018-09-01 05:00:00+03:00  11.420000
# 2018-09-01 06:00:00+03:00  11.614167
# 2018-09-01 07:00:00+03:00  17.665000

# %%
df_lagged_features = pd.read_csv("./sample_time_series_data_with_lagged_features.csv")
df_lagged_features.head()
# Out:
#            0          1          2          3          4          5  \
# 0  13.150000  14.022500  18.605833  22.589167  21.016667  17.665000
# 1  12.806667  13.150000  14.022500  18.605833  22.589167  21.016667
# 2  16.550000  12.806667  13.150000  14.022500  18.605833  22.589167
# 3  11.805833  16.550000  12.806667  13.150000  14.022500  18.605833
# 4  12.878333  11.805833  16.550000  12.806667  13.150000  14.022500
#
#            6          7          8          9
# 0  11.614167  11.420000  15.800000  17.541667
# 1  17.665000  11.614167  11.420000  15.800000
# 2  21.016667  17.665000  11.614167  11.420000
# 3  22.589167  21.016667  17.665000  11.614167
# 4  18.605833  22.589167  21.016667  17.665000

# %%
import seaborn as sns
# Create a heatmap
plt.figure(figsize=(6, 5))
sns.heatmap(df_lagged_features.corr(),cmap="coolwarm", annot=True, fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()
